# %%
import numpy as np
import pickle
from tensorflow.keras.models import load_model

# %%
model = load_model("../models/modelSave/model_3.keras")

# with open("../models/modelSave/model_3_station_offset.pkl", "rb") as f:
#     station_offset = pickle.load(f)
    
station_offset = 0

# %% [markdown]
# hora float campo 13
#
# hora sin campo 14
#
# hora cos campo 15

# %%
initial_date = np.datetime64('2019-01-01 10:35:00')
final_date = np.datetime64('2019-01-01 11:35:00')

# %%
X_test_context = np.array([[ 2.0220000e+03,  1.0000000e+00,  1.0000000e+00,  0.0000000e+00,
                             0.0000000e+00,  0.0000000e+00,  0.0000000e+00,  0.0000000e+00,
                             1.0000000e+00,  1.0222901e+00, -1.9767950e+00, -1.3743014e+00,
                             1.5918056e+01, -8.5510045e-01, -5.1846236e-01, -5.0000000e-01,
                            -8.6602539e-01,  9.7166662e+00]], dtype=np.float32)

start_test_input = np.array([[607]], dtype=np.int32)
end_test_input   = np.array([[0]], dtype=np.int32) # Vacio

probs = model.predict({ 
                       "context": X_test_context, 
                       "start_station_input": start_test_input,
                        "end_station_input": end_test_input
}) 
pred_idx = np.argmax(probs, axis=1) 
pred_stations = pred_idx + station_offset

print(f"Predicted end station: {pred_stations}")
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# Cell In[7], line 10
#       7 start_test_input = np.array([[607]], dtype=np.int32)
#       8 end_test_input   = np.array([[]], dtype=np.int32) # Vacio
# ---> 10 probs = model.predict({
#      11                        "context": X_test_context,
#      12                        "start_station_input": start_test_input,
#      13                         "end_station_input": end_test_input
#      14 })
#      15 pred_idx = np.argmax(probs, axis=1)
#      16 pred_stations = pred_idx + station_offset
#
# File c:\Users\burvu\miniconda3\envs\tfm\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
# ...
